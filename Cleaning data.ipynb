# %% [markdown]
# # Cleaning data of the levels of the rhine from 2000 to 2021

# %% [markdown]
# # Table of contents
#
# * [Import data](#import)
# * [Null values](#null-values)

# %% [markdown]
# ## Import data <a class="anchor" id="import"></a>

# %%
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import glob
import os

# %%
#read in all 20 datasets (from 2000 to 2021) into one dataframe and add a column of year:
all_files = glob.glob("data/Rheinpegel/*.csv")

level_00_21 = pd.concat(pd.concat([pd.Series([y]*31),pd.read_csv(f, sep=';')], axis=1) for f, y in zip(all_files, range(2000, 2022)))
#

display(level_00_21)
# Out:
#        0  Tag  Januar  Februar  Maerz  April  Mai   Juni  Juli  August  \
# 0   2000    1     684    381.0    457  401.0  285  276.0   209     376
# 1   2000    2     605    499.0    456  478.0  289  299.0   207     376
# 2   2000    3     554    532.0    513  483.0  291  383.0   221     356
# 3   2000    4     511    492.0    577  458.0  299  415.0   227     358
# 4   2000    5     487    455.0    616  429.0  303  390.0   243     349
# ..   ...  ...     ...      ...    ...    ...  ...    ...   ...     ...
# 26  2021   27     441    297.0    230  133.0  370  352.0   459     267
# 27  2021   28     406    289.0    223  130.0  372  356.0   445     256
# 28  2021   29     397      NaN    220  127.0  363  346.0   452     248
# 29  2021   30     489      NaN    219  121.0  350  339.0   446     242
# 30  2021   31     630      NaN    220    NaN  327    NaN   427     241
#
#     September  Oktober  November  Dezember
# 0       227.0      252     213.0       371
# ...

# %%
#rename the new column into 'year':
level_00_21 = level_00_21.rename(columns={0:'year'})

# %% [markdown]
# ## Look at the null-values <a class="anchor" id="null-values"> </a>

# %%
level_00_21.isna().sum()
# Out:
# year          0
# Tag           0
# Januar        0
# Februar      60
# Maerz         0
# April        22
# Mai           0
# Juni         22
# Juli          0
# August        0
# September    22
# Oktober       0
# November     22
# Dezember      0
# dtype: int64

# %% [markdown]
# ### Looking at the month seperately

# %%
level_00_21[level_00_21['September'].isna()]
# Out:
#     year  Tag  Januar  Februar  Maerz  April  Mai   Juni  Juli  August  \
# 30  2000   31     281      NaN    344    NaN  273    NaN   349     229
# 30  2001   31     455      NaN    734    NaN  313    NaN   282     174
# 0   2002    1     590    604.0    823  415.0  288  340.0   258     228
# 30  2003   31     480      NaN    208    NaN  233  157.0   156      86
# 30  2004   31     302      NaN    237    NaN  204    NaN   193     294
# 30  2005   31     258      NaN    358    NaN  279    NaN   195     344
# 30  2006   31     125      NaN    541    NaN  458    NaN   138     306
# 30  2007   31     290      NaN    372    NaN  269    NaN   301     254
# 30  2008   31     265      NaN    426    NaN  261    NaN   227     202
# 30  2009   31     239      NaN    475    NaN  287    NaN   269     148
# 30  2010   31     227      NaN    356    NaN  253    NaN   266     373
# 30  2011   31     344      NaN    153    NaN   80    NaN   260     196
# ...

# %% [markdown]
# One NaN in 1th September 2002 I have to deal with; no NaN at 31th

# %%
level_00_21[level_00_21['April'].isna()]
# Out:
#     year  Tag  Januar  Februar  Maerz  April  Mai   Juni  Juli  August  \
# 30  2000   31     281      NaN    344    NaN  273    NaN   349     229
# 30  2001   31     455      NaN    734    NaN  313    NaN   282     174
# 30  2002   31     684      NaN    443    NaN  335    NaN   237     287
# 30  2003   31     480      NaN    208    NaN  233  157.0   156      86
# 30  2004   31     302      NaN    237    NaN  204    NaN   193     294
# 30  2005   31     258      NaN    358    NaN  279    NaN   195     344
# 30  2006   31     125      NaN    541    NaN  458    NaN   138     306
# 30  2007   31     290      NaN    372    NaN  269    NaN   301     254
# 30  2008   31     265      NaN    426    NaN  261    NaN   227     202
# 30  2009   31     239      NaN    475    NaN  287    NaN   269     148
# 30  2010   31     227      NaN    356    NaN  253    NaN   266     373
# 30  2011   31     344      NaN    153    NaN   80    NaN   260     196
# ...

# %%
#NaN in April are fine. They all can be dropped

# %%
level_00_21[level_00_21['Juni'].isna()]
# Out:
#     year  Tag  Januar  Februar  Maerz  April  Mai  Juni  Juli  August  \
# 30  2000   31     281      NaN    344    NaN  273   NaN   349     229
# 30  2001   31     455      NaN    734    NaN  313   NaN   282     174
# 30  2002   31     684      NaN    443    NaN  335   NaN   237     287
# 0   2003    1     668    503.0    239  207.0  186   NaN   161     154
# 30  2004   31     302      NaN    237    NaN  204   NaN   193     294
# 30  2005   31     258      NaN    358    NaN  279   NaN   195     344
# 30  2006   31     125      NaN    541    NaN  458   NaN   138     306
# 30  2007   31     290      NaN    372    NaN  269   NaN   301     254
# 30  2008   31     265      NaN    426    NaN  261   NaN   227     202
# 30  2009   31     239      NaN    475    NaN  287   NaN   269     148
# 30  2010   31     227      NaN    356    NaN  253   NaN   266     373
# 30  2011   31     344      NaN    153    NaN   80   NaN   260     196
# ...

# %%
# One NaN at 1th of June 2003, but  no on 31th

# %%
level_00_21[level_00_21['November'].isna()]
# Out:
#     year  Tag  Januar  Februar  Maerz  April  Mai   Juni  Juli  August  \
# 30  2000   31     281      NaN    344    NaN  273    NaN   349     229
# 30  2001   31     455      NaN    734    NaN  313    NaN   282     174
# 30  2002   31     684      NaN    443    NaN  335    NaN   237     287
# 30  2003   31     480      NaN    208    NaN  233  157.0   156      86
# 30  2004   31     302      NaN    237    NaN  204    NaN   193     294
# 30  2005   31     258      NaN    358    NaN  279    NaN   195     344
# 30  2006   31     125      NaN    541    NaN  458    NaN   138     306
# 30  2007   31     290      NaN    372    NaN  269    NaN   301     254
# 30  2008   31     265      NaN    426    NaN  261    NaN   227     202
# 30  2009   31     239      NaN    475    NaN  287    NaN   269     148
# 30  2010   31     227      NaN    356    NaN  253    NaN   266     373
# 30  2011   31     344      NaN    153    NaN   80    NaN   260     196
# ...

# %%
# NaN in November are alright and can be dropped

# %%
level_00_21[level_00_21['Februar'].isna()]
# Out:
#     year  Tag  Januar  Februar  Maerz  April  Mai   Juni  Juli  August  \
# 29  2000   30     240      NaN    338  283.0  277  224.0   357     232
# 30  2000   31     281      NaN    344    NaN  273    NaN   349     229
# 28  2001   29     533      NaN    802  531.0  334  351.0   302     183
# 29  2001   30     503      NaN    758  545.0  321  362.0   289     177
# 30  2001   31     455      NaN    734    NaN  313    NaN   282     174
# 28  2002   29     639      NaN    533  261.0  313  267.0   264     266
# 29  2002   30     687      NaN    485  279.0  314  262.0   248     305
# 30  2002   31     684      NaN    443    NaN  335    NaN   237     287
# 28  2003   29     424      NaN    221  175.0  244  166.0   153      71
# 29  2003   30     440      NaN    209  175.0  236  161.0   157      77
# 30  2003   31     480      NaN    208    NaN  233  157.0   156      86
# 29  2004   30     323      NaN    253  190.0  203  198.0   206     269
# ...

# %%
# NaN in february are all right too.

# %% [markdown]
# ### Looking closer at the NaN of June 2003 and September 2002

# %%
display(level_00_21[level_00_21['year']==2003][['Tag','Juni']])
display(level_00_21[level_00_21['year']==2002][['Tag','September']])
# Out:
#     Tag   Juni
# 0     1    NaN
# 1     2  240.0
# 2     3  238.0
# 3     4  245.0
# 4     5  231.0
# 5     6  223.0
# 6     7  221.0
# 7     8  221.0
# 8     9  219.0
# 9    10  225.0
# 10   11  237.0
# 11   12  238.0
# 12   13  238.0
# 13   14  233.0
# 14   15  223.0
# 15   16  218.0
# 16   17  223.0
# 17   18  236.0
# 18   19  225.0
# 19   20  213.0
# 20   21  214.0
# 21   22  215.0
# 22   23  207.0
# 23   24  201.0
# 24   25  193.0
# 25   26  176.0
# 26   27  172.0
# 27   28  171.0
# 28   29  166.0
# 29   30  161.0
# 30   31  157.0
#     Tag  September
# 0     1        NaN
# 1     2      259.0
# 2     3      243.0
# 3     4      232.0
# 4     5      234.0
# 5     6      273.0
# 6     7      273.0
# 7     8      264.0
# 8     9      255.0
# 9    10      247.0
# 10   11      242.0
# 11   12      235.0
# 12   13      243.0
# 13   14      252.0
# 14   15      256.0
# 15   16      244.0
# 16   17      225.0
# 17   18      209.0
# 18   19      200.0
# 19   20      192.0
# ...

# %%
# I assume that the data was not properly put into the dataset and that it should be shifted by one day.

# %%
level_00_21.loc[level_00_21['year']==2003,'Juni']= level_00_21.loc[level_00_21['year']==2003,'Juni'].shift(periods=-1)
level_00_21.loc[level_00_21['year']==2002,'September'] = level_00_21.loc[level_00_21['year']==2002,'September'].shift(periods=-1)

# %%
display(level_00_21[level_00_21['year']==2003][['Tag','Juni']])
display(level_00_21[level_00_21['year']==2002][['Tag','September']])
# Out:
#     Tag   Juni
# 0     1  240.0
# 1     2  238.0
# 2     3  245.0
# 3     4  231.0
# 4     5  223.0
# 5     6  221.0
# 6     7  221.0
# 7     8  219.0
# 8     9  225.0
# 9    10  237.0
# 10   11  238.0
# 11   12  238.0
# 12   13  233.0
# 13   14  223.0
# 14   15  218.0
# 15   16  223.0
# 16   17  236.0
# 17   18  225.0
# 18   19  213.0
# 19   20  214.0
# 20   21  215.0
# 21   22  207.0
# 22   23  201.0
# 23   24  193.0
# 24   25  176.0
# 25   26  172.0
# 26   27  171.0
# 27   28  166.0
# 28   29  161.0
# 29   30  157.0
# 30   31    NaN
#     Tag  September
# 0     1      259.0
# 1     2      243.0
# 2     3      232.0
# 3     4      234.0
# 4     5      273.0
# 5     6      273.0
# 6     7      264.0
# 7     8      255.0
# 8     9      247.0
# 9    10      242.0
# 10   11      235.0
# 11   12      243.0
# 12   13      252.0
# 13   14      256.0
# 14   15      244.0
# 15   16      225.0
# 16   17      209.0
# 17   18      200.0
# 18   19      192.0
# 19   20      186.0
# ...

# %% [markdown]
# ## Create a new dataframe with two columns: date and value

# %%
#put all values in one column + create the date column as: d = date(year, month, day)
values=[]
cal=[]
for i in range(1,13):
    for j in range(682):
        condition= level_00_21.iloc[:,i+1].isnull().values
        if condition[j] == False:
            #print(level_00_21.iloc[j,i+1])
            values.append(level_00_21.iloc[j,i+1])
            
            day=level_00_21.iloc[j,1]
            y=level_00_21.iloc[j,0]
            d = date(y, i, day)
            cal.append(d)

# %%
#print(len(cal), len(values))

rhein_level = pd.DataFrame({'date': cal, 'level': values})
display(rhein_level)
# Out:
#             date  level
# 0     2000-01-01  684.0
# 1     2000-01-02  605.0
# 2     2000-01-03  554.0
# 3     2000-01-04  511.0
# 4     2000-01-05  487.0
# ...          ...    ...
# 8031  2021-12-27  167.0
# 8032  2021-12-28  195.0
# 8033  2021-12-29  252.0
# 8034  2021-12-30  328.0
# 8035  2021-12-31  397.0
#
# [8036 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
plt.scatter(x=rhein_level['date'], y=rhein_level['level'])

# %%
plt.figure(figsize=(20, 6))
sns.lineplot(x=rhein_level['date'], y=rhein_level['level'])
sns.lineplot(x=rhein_level['date'], y=rhein_level['level'].rolling(window=300).mean())
#rhein_level.rolling(window =300, ).mean().plot()
plt.show()

# %%
roll1= rhein_level.rolling(window =300).mean()
print(roll1)

plt.figure(figsize=(20, 6))
roll1.plot()
#roll1['level'].rolling(window =300).mean().plot()
#sns.lineplot(roll1)
#sns.lineplot(roll1.rolling(window=300).mean())
##rhein_level.rolling(window =300, ).mean().plot()
plt.show()
# Out:
#            level
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 8031  274.073333
# 8032  273.643333
# 8033  273.286667
# 8034  273.240000
# 8035  273.480000
#
# [8036 rows x 1 columns]

# %% [markdown]
# ## Store data

# %%
rhein_level.to_csv('data/rhine_level.csv', index=False)

# %%
import pymysql
from sqlalchemy import create_engine

# %%
from getpass import getpass  # To get the password without showing the input

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/rhine_level'
engine = create_engine(connection_string)

# %%
#rhein_level.to_sql('level', con=engine, if_exists='fail', index=False)

# %% [markdown]
# ## Explore minima and maxima

# %%
level_00_21.min()
#level_00_21.max()

# %%
rhein_level[rhein_level['level'] == rhein_level['level'].min()]

# %%
rhein_level[rhein_level['level'] == rhein_level['level'].max()]

# %%
# How many days is the level below the minimum for shipping traffic: 105cm  / 150cm for full load

# %%
# I will create an average of every month and put this into a new dataframe with all years.

# %%
#Making columns all lower cases:
cols = []
for column in level_01_21.columns:
    cols.append(column.lower())
level_01_21.columns = cols

display(level_01_21.head(31))
display(level_01_21.tail())

# %%
level_01_21.columns[12]

# %%
level_01_21[level_01_21['tag'] == 31]

# %%
level_01_21.iloc[12][0]

# %%
level_01_21.iloc[712,0]

# %%
level_2001['januar'].mean()

# %%
level_2001.iloc[:,1].mean()

# %%
mean_level= []

for i in range (1,13):
    mean_level.append(round(level_2001.iloc[:,i].mean(),2))

display(mean_level)
